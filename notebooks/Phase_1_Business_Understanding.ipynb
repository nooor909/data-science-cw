# %% [markdown]
# # Phase 1: Business Understanding
#
# **CRISP-DM Phase Description:**
# This phase focuses on understanding the project objectives and requirements from a business perspective, then converting this knowledge into a data mining problem definition and a preliminary plan designed to achieve the objectives.
#
# ---

# %% [markdown]
# ### Task 1: Determine Business Objectives
#
# The first objective of the data analyst is to thoroughly understand, from a business perspective, what the customer really wants to accomplish. This involves:
#
# - **Background:** Identify the organisational context and the business area the project relates to.
# - **Business Objectives:** Clearly state the primary question or problem the business wants to solve.
# - **Business Success Criteria:** Define the measurable criteria that determine whether the project's outcome is considered a success from the business's point of view (e.g., "reduce customer churn by 15%", "improve prediction accuracy to 90%").
#
# **Instructions:** In the cells below, define your business objectives, background context, and success criteria as Python variables (strings or dictionaries). This ensures your business logic is documented directly in the notebook's code state.

# %%
# Define business objectives here.
# Example:
# business_objectives = {
#     "background": "Describe the organisational context and business area...",
#     "primary_objective": "What is the main business question or problem?",
#     "success_criteria": [
#         "Criterion 1: e.g., Reduce X by Y%",
#         "Criterion 2: e.g., Achieve Z accuracy"
#     ]
# }

business_objectives = {
    "background": "Grant application screening is a process for non-profit and an education driven funding platform. This is because they recieve large numbers of applications and must decide which ones should be approved using limited time and resources.",

    "primary_objective": "The primary objective is to develop and create a data driven solution that can predict the chances of grant application approval.",
    
    "success_criteria": [
        "Criteria 1: Build a classification model that predicts project approval with strong and reliable performance.",
        "Criteria 2: Generate results that are interpretable and useful for supporting reviewer decision making.",
        "Criteria 3: Identify the most important variables and cases that influence grant approval decisions.",
        "Criteria 4: Ensure fairness by evaluating approval rates across different school groups."
    ]
}

# %%
# Display the defined objectives in a readable format
for key, value in business_objectives.items():
    print(f">> {key.upper().replace('_', ' ')}:")
    if isinstance(value, list):
        for item in value:
            print(f"   - {item}")
    else:
        print(f"   {value}")
    print()
# Out:
# >> BACKGROUND:
#    Grant application screening is a process for non-profit and an education driven funding platform. This is because they recieve large numbers of applications and must decide which ones should be approved using limited time and resources.
#
# >> PRIMARY OBJECTIVE:
#    The primary objective is to develop and create a data driven solution that can predict the chances of grant application approval.
#
# >> SUCCESS CRITERIA:
#    - Criteria 1: Build a classification model that predicts project approval with strong and reliable performance.
#    - Criteria 2: Generate results that are interpretable and useful for supporting reviewer decision making.
#    - Criteria 3: Identify the most important variables and cases that influence grant approval decisions.
#    - Criteria 4: Ensure fairness by evaluating approval rates across different school groups.

# %% [markdown]
# ---
# ### Task 2: Assess Situation
#
# This task involves a more detailed fact-finding about all of the resources, constraints, assumptions, and other factors that should be considered in determining the data analysis goal and project plan. Key areas to assess:
#
# - **Resources Inventory:** Personnel, data sources, computing resources, and software available.
# - **Requirements, Assumptions, and Constraints:** Project schedule, legal/ethical considerations, data access limitations, and budget.
# - **Risks and Contingencies:** Identify potential risks (e.g., data unavailability, quality issues, privacy concerns) and how to mitigate them.
# - **Terminology Glossary:** Define key domain-specific terms relevant to the project.
# - **Costs and Benefits:** A cost-benefit analysis of the project.
#
# **Instructions:** Document your situation assessment as a structured dictionary or set of variables.

# %% [markdown]
# This section evaluates the current situation present for the making of this project. This includes available resources, project requirements, assumptions, constraints, and potential risks associated with the project. Additionaly, it defines key terminologies for the most used and most important terminologies that will be included and mentioned throughout the overall project.

# %%
# Assess the current situation here.
# Document resources, requirements, assumptions, constraints, and risks.

situation_assessment = {
    "Resources": {
        "personnel": [  "Data Science University Student - Level 5",
                        "Module Leader and Tutorial Assistants - Domain Expert"],      # e.g., ["Data Scientist", "Domain Expert"]
        "data_sources": ["DonorsChoose Application Screening dataset (Kaggle) - CSV file"],   # e.g., ["Internal DB", "Public API", "CSV files"]
        "computing": "Local machine using Visual Studio Code and Miniconda Environment (grantenv)",
        "software": [   "python 3.12.13", 
                        "pandas", 
                        "Numpy", 
                        "matplotlb", 
                        "scikit-learn", 
                        "seaborn", 
                        "Visual Studio Code", 
                        "GitHub"],
    },

    "Requirements": ["Must comply with the CRISP-DM Cycle and methodology with all it's 6 phases.",
                     "Reports and a poster to be made with the final findings and results of every phase.", 
                     "Must include ethical and unbiased analysis when needed."],
                            
    "Assumptions": ["The dataset is highly representative of real-world applications.",
                    "No major missing or corrupted data prevents analysis.",
                    "Historical approval decisions do not affect todays approval chances and instead reflect meaningful patterns."],        # e.g., ["Data is representative of the population"]

    "Constraints": ["Limited time due to a set deadline.",
                    "Limited computing resources.",
                    "Impact on preocessing speed due to a large dataset."],
    "Risks_and_contingencies": [

        {"risk": "Bias in approval predictions.", 
        "probability": "High", 
        "mitigation": "Conduct fairness analysis and compare subgroup outcomes."},

        {"risk": "Model performs poorly or does not meet the goal or success criteria.", 
        "probability": "Medium", 
        "mitigation": "Try multiple models and perform proper evaluations."},
    ],
    "Terminology": {
        "Grant Application": "A request submitted for funding support.",
        "Approval": "A decision indicating that a grant request is accepted.",
        "Target Variable": "The main variable used for predicting.",
        "Feature": "An input variable used in prediction.",
    },
    "cost_benefit": "Automating the initial screening od grant applications can significantly reduce manual workload and speed up decision making. Although, there may be a risk of potential bias or incorrect predictions, so results must be interpreted carefully and used as support rather than replacement for human judgement."
}

# %%
# Display situation assessment
import json
print(json.dumps(situation_assessment, indent=2))
# Out:
# {
#   "Resources": {
#     "personnel": [
#       "Data Science University Student - Level 5",
#       "Module Leader and Tutorial Assistants - Domain Expert"
#     ],
#     "data_sources": [
#       "DonorsChoose Application Screening dataset (Kaggle) - CSV file"
#     ],
#     "computing": "Local machine using Visual Studio Code and Miniconda Environment (grantenv)",
#     "software": [
#       "python 3.12.13",
#       "pandas",
#       "Numpy",
#       "matplotlb",
#       "scikit-learn",
#       "seaborn",
#       "Visual Studio Code",
#       "GitHub"
#     ]
#   },
#   "Requirements": [
#     "Must comply with the CRISP-DM Cycle and methodology with all it's 6 phases.",
#     "Reports and a poster to be made with the final findings and results of every phase.",
#     "Must include ethical and unbiased analysis when needed."
#   ],
#   "Assumptions": [
#     "The dataset is highly representative of real-world applications.",
#     "No major missing or corrupted data prevents analysis.",
#     "Historical approval decisions do not affect todays approval chances and instead reflect meaningful patterns."
#   ],
#   "Constraints": [
#     "Limited time due to a set deadline.",
#     "Limited computing resources.",
#     "Impact on preocessing speed due to a large dataset."
#   ],
#   "Risks_and_contingencies": [
#     {
#       "risk": "Bias in approval predictions.",
#       "probability": "High",
#       "mitigation": "Conduct fairness analysis and compare subgroup outcomes."
#     },
#     {
#       "risk": "Model performs poorly or does not meet the goal or success criteria.",
#       "probability": "Medium",
#       "mitigation": "Try multiple models and perform proper evaluations."
#     }
#   ],
#   "Terminology": {
#     "Grant Application": "A request submitted for funding support.",
#     "Approval": "A decision indicating that a grant request is accepted.",
#     "Target Variable": "The main variable used for predicting.",
#     "Feature": "An input variable used in prediction."
#   },
#   "cost_benefit": "Automating the initial screening od grant applications can significantly reduce manual workload and speed up decision making. Although, there may be a risk of potential bias or incorrect predictions, so results must be interpreted carefully and used as support rather than replacement for human judgement."
# }

# %% [markdown]
# ---
# ### Task 3: Determine Data Mining Goals
#
# A business goal states objectives in business terminology. A data mining goal states project objectives in technical terms. This task converts the business objectives identified in Task 1 into specific, measurable data mining goals:
#
# - **Data Mining Problem Type:** Classify the problem (e.g., classification, regression, clustering, anomaly detection, association rule mining, etc.).
# - **Data Mining Goals:** State the technical objectives clearly (e.g., "Build a classification model to predict [target variable] with an F1-score ≥ 0.85").
# - **Data Mining Success Criteria:** Define the technical metrics that will be used to evaluate the model's performance (e.g., accuracy, precision, recall, RMSE, silhouette score).
#
# **Instructions:** Map your business objectives to concrete data mining goals.

# %%
# Define data mining goals here.

data_mining_goals = {
    "problem_type": "Binary Classification",

    "target_variable": "project_is_approved",

    "technical_goals": [
        "Goal 1: Build a model to predict whethera grant application will be approved with an accuracy > 80%",
        "Goal 2: Perform feature engineering and preprocessing to improve model performance.",
        "Goal 3: Compare multiple models to identify the best-performing approach.",
    ],
    "success_metrics": [
        "Metric 1: F1-Score >= 0.80 to balance precision and recall.",
        "Metric 2: ROC-AUC >= 0.60 to access model performance across different thresholds.",
        "Metric 3: Precision and Recall to evaluate classification quality."
    ]
}

# %%
# Display the mapping from business objectives to data mining goals
print("=" * 60)
print("BUSINESS TO DATA MINING GOAL MAPPING")
print("=" * 60)
print(f"\nBusiness Objective : {business_objectives['primary_objective']}")
print(f"Problem Type       : {data_mining_goals['problem_type']}")
print(f"Target Variable    : {data_mining_goals['target_variable']}")
print(f"\nTechnical Goals:")
for goal in data_mining_goals['technical_goals']:
    print(f"  - {goal}")
print(f"\nSuccess Metrics:")
for metric in data_mining_goals['success_metrics']:
    print(f"  - {metric}")
# Out:
# ============================================================
# BUSINESS TO DATA MINING GOAL MAPPING
# ============================================================
#
# Business Objective : The primary objective is to develop and create a data driven solution that can predict the chances of grant application approval.
# Problem Type       : Binary Classification
# Target Variable    : project_is_approved
#
# Technical Goals:
#   - Goal 1: Build a model to predict whethera grant application will be approved with an accuracy > 85%
#   - Goal 2: Perform feature engineering and preprocessing to improve model performance.
#   - Goal 3: Compare multiple models to identify the best-performing approach.
#
# Success Metrics:
#   - Metric 1: F1-Score to balance precision and recall.
#   - Metric 2: AUC-ROC >= 0.85 to access model performance across different thresholds.
#   - Metric 3: Precision and Recall to evaluate classification quality.

# %% [markdown]
# ---
# ### Task 4: Produce Project Plan
#
# Describe the intended plan for achieving the data mining goals and thereby achieving the business goals. The plan should specify:
#
# - **Tools and Techniques:** The data mining tools (libraries, frameworks) and modelling techniques you plan to use.
# - **Project Plan / Timeline:** A step-by-step plan with estimated durations for each remaining CRISP-DM phase.
# - **Dependencies:** Any dependencies between tasks or on external factors.
# - **Initial Assessment of Tools and Techniques:** A brief justification for why the chosen tools and techniques are appropriate.
#
# **Instructions:** Outline your full project plan as a structured data object below.

# %%
# Produce your project plan here.

project_plan = {
    "tools": [
        "Python",
        "pandas", 
        "Numpy",
        "scikit-learn", 
        "matplotlib", 
        "seaborn", 
        "Visual Studio Code",
        "GitHub",
    ],
    "techniques": [
        "Exploratrory Data Analysis (EDA)",
        "Data cleaning and preprocessing",
        "Logistic", 
        "Regression", 
        "Random Forest", 
        "Classification Models",
        "Model evaluation and comparison",
    ],
    "timeline": [
        {"phase": "Business Understanding",  "duration": "Day 1", "status": "Completed"},
        {"phase": "Data Understanding",  "duration": "Day 2", "status": "Completed"},
        {"phase": "Data Preparation",    "duration": "Days 3-5", "status": "Completed"},
        {"phase": "Modelling",           "duration": "Day 6", "status": "Not Started"},
        {"phase": "Evaluation",          "duration": "Days 7-8", "status": "Not Started"},
        {"phase": "Deployment",          "duration": "Day 9",   "status": "Not Started"}
    ],
    "dependencies": [
        "Dataset must be correctly loaded and in the right file.",
        "Notebook structure must follow the CRISP-DM methodology.",
        "Required Python libraries must be installed in the environment.",
    ],
    "tool_justification":[  
        "Python is chosen for its strong data science ecosystem.",
        "Pandas and Numpy enable efficient data handling, while scikit-learn provides reliable machine learning algorithms.",
        "Mathplotlib and seaborn are used for visualization and data exploration.",
    ],
}

# %%
# Display the project plan
print("=" * 60)
print("PROJECT PLAN")
print("=" * 60)

print("\nTools:", ", ".join(project_plan['tools']) if project_plan['tools'] else "[Not yet defined]")
print("Techniques:", ", ".join(project_plan['techniques']) if project_plan['techniques'] else "[Not yet defined]")

print("\nTimeline:")
if project_plan['timeline']:
    for item in project_plan['timeline']:
        status = item.get("status", "N/A")
        phase_name = item.get("phase", "N/A")
        duration = item.get("duration" ,"N/A")
        print(f" [{status:^12}] {phase_name:<25} | {duration}")
else:
    print("  [Not yet defined]")

print("\nDependencies:")
for dep in project_plan['dependencies']:
    print(f"  - {dep}")

print(f"\nTool Justification: {project_plan['tool_justification']}")
# Out:
# ============================================================
# PROJECT PLAN
# ============================================================
#
# Tools: Python, pandas, Numpy, scikit-learn, matplotlib, seaborn, Visual Studio Code, GitHub
# Techniques: Exploratrory Data Analysis (EDA), Data cleaning and preprocessing, Logistic, Regression, Random Forest, Classification Models, Model evaluation and comparison
#
# Timeline:
#  [ Completed  ] Business Understanding    | Day 1
#  [ Completed  ] Data Understanding        | Day 2
#  [ Completed  ] Data Preparation          | Days 3-5
#  [Not Started ] Modelling                 | Day 6
#  [Not Started ] Evaluation                | Days 7-8
#  [Not Started ] Deployment                | Day 9
#
# Dependencies:
#   - Dataset must be correctly loaded and in the right file.
#   - Notebook structure must follow the CRISP-DM methodology.
#   - Required Python libraries must be installed in the environment.
#
# Tool Justification: ['Python is chosen for its strong data science ecosystem.', 'Pandas and Numpy enable efficient data handling, while scikit-learn provides reliable machine learning algorithms.', 'Mathplotlib and seaborn are used for visualization and data exploration.']

# %%
# Optional: Summarise all Phase 1 outputs for reference in subsequent phases
print("=" * 60)
print("PHASE 1 SUMMARY: BUSINESS UNDERSTANDING")
print("=" * 60)
print(f"\nPrimary Objective  : {business_objectives['primary_objective']}")
print(f"Problem Type       : {data_mining_goals['problem_type']}")
print(f"Target Variable    : {data_mining_goals['target_variable']}")
print(f"Tools Planned      : {', '.join(project_plan['tools']) if project_plan['tools'] else 'TBD'}")
print(f"Techniques Planned : {', '.join(project_plan['techniques']) if project_plan['techniques'] else 'TBD'}")
# Out:
# ============================================================
# PHASE 1 SUMMARY: BUSINESS UNDERSTANDING
# ============================================================
#
# Primary Objective  : The primary objective is to develop and create a data driven solution that can predict the chances of grant application approval.
# Problem Type       : Binary Classification
# Target Variable    : project_is_approved
# Tools Planned      : Python, pandas, Numpy, scikit-learn, matplotlib, seaborn, Visual Studio Code, GitHub
# Techniques Planned : Exploratrory Data Analysis (EDA), Data cleaning and preprocessing, Logistic, Regression, Random Forest, Classification Models, Model evaluation and comparison
