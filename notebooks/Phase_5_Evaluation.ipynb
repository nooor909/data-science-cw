# %% [markdown]
# # Phase 5: Evaluation
#
# **CRISP-DM Phase Description:**
# At this stage, the model(s) appear to have high quality from a technical standpoint. Before proceeding to final deployment, it is important to evaluate the model more thoroughly and review the steps that were executed to construct it, to be certain the model properly achieves the business objectives. A key objective is to determine if there is some important business issue that has not been sufficiently considered.
#
# ---

# %%
# Standard imports
import pandas as pd
import numpy as np

# %% [markdown]
# ---
# ### Task 1: Evaluate Results
#
# Assess how well the model(s) meet the **business success criteria** originally defined in **Phase 1 (Business Understanding)**. This is distinct from the technical assessment in Phase 4 — here you ask: *"Does this model actually solve the business problem?"*
#
# Key activities:
# - **Map Technical Metrics to Business Criteria:** Compare the model's performance metrics (from Phase 4) against the business success criteria and data mining success criteria defined in Phase 1.
# - **Business Impact Assessment:** Translate technical performance into business-relevant terms (e.g., "The model's 92% recall means we would catch 92 out of every 100 fraudulent transactions").
# - **Gap Analysis:** Identify any gaps between expected and actual performance.
# - **Approved Models:** List the model(s) that pass the evaluation and the ones that do not.
#
# **Instructions:** Reference the `business_objectives` and `data_mining_goals` dictionaries from Phase 1. Compare each success criterion against the model's actual performance.

# %%
# Evaluate model results against business success criteria.
# Reference your Phase 1 definitions and Phase 4 results.

evaluation = {
    "business_criteria": [
        {
            "criterion": "Build a classification model that predicts project approval with strong and reliable performance.",
            "target": "Model should correctly identify majority of approved projects.",
            "achieved": "Recall for approved projects = 95%",
            "met": True
        },
        {
            "criterion": "Generate results that are interpretable and useful for supporting reviewer decision making.",
            "target": "Model should not classify all projects as approved.",
            "achieved": "Random Forest predicts both approved and non-approved projects.",
            "met": True
        },
    ],

    "technical_criteria": [
        {
            "metric": "F1-Score",
            "target": ">= 0.80",
            "achieved": 0.899,
            "met": True
        },
        {
            "metric": "ROC-AUC",
            "target": ">= 0.60",
            "achieved": 0.545,
            "met": False
        },
    ],

    "overall_assessment": ["The model partially meets the business objectives.",
     "It performs well in identifying approved projects and can support decision-mkaing, but its ability to distinguish between approved and non-approved projects is limited."],
    "approved_models": ["Random Forest"], 
    "rejected_models": ["Logistic Regression", "Gradient Boosting"] 
}

# %%
# Display the evaluation summary
print("=" * 60)
print("EVALUATION AGAINST BUSINESS SUCCESS CRITERIA")
print("=" * 60)

print("\n--- Business Criteria ---")
for c in evaluation['business_criteria']:
    status = 'PASS' if c['met'] else 'FAIL'
    print(f"  [{status}] {c['criterion']}")
    print(f"         Target: {c['target']}  |  Achieved: {c['achieved']}")

print("\n--- Technical Criteria ---")
for c in evaluation['technical_criteria']:
    status = 'PASS' if c['met'] else 'FAIL'
    print(f"  [{status}] {c['metric']}: Target {c['target']}  |  Achieved: {c['achieved']}")

print(f"\nOverall: {evaluation['overall_assessment']}")
print(f"Approved models: {evaluation['approved_models']}")
print(f"Rejected models: {evaluation['rejected_models']}")
# Out:
# ...
# EVALUATION AGAINST BUSINESS SUCCESS CRITERIA
# ...
#
# --- Business Criteria ---
#   [PASS] Build a classification model that predicts project approval with strong and reliable performance.
#          Target: Model should correctly identify majority of approved projects.  |  Achieved: Recall for approved projects = 95%
#   [PASS] Generate results that are interpretable and useful for supporting reviewer decision making.
#          Target: Model should not classify all projects as approved.  |  Achieved: Random Forest predicts both approved and non-approved projects.
#
# --- Technical Criteria ---
#   [PASS] F1-Score: Target >= 0.80  |  Achieved: 0.899
#   [FAIL] ROC-AUC: Target >= 0.60  |  Achieved: 0.545
#
# Overall: ['The model partially meets the business objectives.', 'It performs well in identifying approved projects and can support decision-mkaing, but its ability to distinguish between approved and non-approved projects is limited.']
# Approved models: ['Random Forest']
# ...

# %% [markdown]
# ### Evaluating results Notes
# - The model was evaluated against the original business objective of assisting in the screening of grant applications. The results indicate that the selected model performs well in identifying approved projects, achieving a high recall of approximately 96%. This means the model is effective in capturing the majority of applications that are likely to be approved, which supports its use as a decision-support tool.
#
# - In addition, the model demonstrates the ability to classify both approved and non-approved projects, unlike some alternative models which showed strong bias toward the majority class. This makes it more suitable for practical use in assisting reviewers.
#
# - Therefore, while the model meets several key business objectives, its performance is constrained by class imbalance and limited feature separability. Despite these limitations, it can still provide value by helping prioritise applications and reduce manual workload.

# %% [markdown]
# ---
# ### Task 2: Review Process
#
# Conduct a thorough review of the entire CRISP-DM process executed so far. The goal is to ensure quality assurance — that no important task or factor was overlooked. Consider:
#
# - **Completeness Check:** Were all relevant data sources considered? Were the data preparation steps sufficient?
# - **Methodology Review:** Were appropriate techniques used at each stage? Were there alternatives worth exploring?
# - **Data Leakage Check:** Did any information from the test set leak into the training process?
# - **Bias and Fairness:** Could the model introduce or amplify any biases? Is the model fair across different subgroups?
# - **Reproducibility:** Can the entire pipeline be reproduced from scratch with consistent results?
#
# **Instructions:** Complete the process review checklist below and document any concerns.

# %%
# Review the end-to-end process.

process_review = {
    "checklist": [
        {
            "item": "All relevant data sources were considered",
            "status": "Yes",
            "notes": "A single comprehensive dataset was used containing all necessary features for the project."
        },
        {
            "item": "Data preparation was thorough and documented",
            "status": "Yes",
            "notes": "Included cleaning, handling missing values, encoding categorical variables, and feature engineering."
        },
        {
            "item": "No data leakage between train and test sets",
            "status": "Yes",
            "notes": "Train/test split was performed before modelling and no test data was used during training."
        },
        {
            "item": "Multiple modelling techniques were compared",
            "status": "Yes",
            "notes": "Logistic Regression, Random Forest, and Gradient Boosting were implemented and evaluated."
        },
        {
            "item": "Hyperparameters were tuned appropriately",
            "status": "Yes",
            "notes": "GridSearchCV was applied to Random Forest to improve performance."
        },
        {
            "item": "Results are reproducible (random seed set)",
            "status": "Yes",
            "notes": "A fixed random seed was used in data splitting and model training."
        },
        {
            "item": "Bias and fairness have been considered",
            "status": "Partial",
            "notes": "Class imbalance was identified and partially addressed using class weighting, but no subgroup fairness analysis was conducted."
        },
        {
            "item": "Ethical implications have been reviewed",
            "status": "Partial",
            "notes": "Potential bias in approval predictions was acknowledged, but deeper ethical analysis could be expanded."
        }
    ],

    "overall_quality": "Satisfactory", 
    "areas_for_improvement": [
        "Apply advanced techniques to better handle class imbalance (e.g., SMOTE)",
        "Improve model performance, especially ROC-AUC",
        "Conduct deeper fairness analysis across different groups",
        "Explore additional feature engineering to improve class separation"
    ]
}

# %%
# Display the process review
print("=== Process Review Checklist ===")
for item in process_review['checklist']:
    print(f"  [{item['status']:^8}] {item['item']}")
    if item['notes']:
        print(f"           Note: {item['notes']}")

print(f"\nOverall Quality: {process_review['overall_quality']}")
if process_review['areas_for_improvement']:
    print("Areas for Improvement:")
    for area in process_review['areas_for_improvement']:
        print(f"  - {area}")
# Out:
# === Process Review Checklist ===
#   [  Yes   ] All relevant data sources were considered
#            Note: A single comprehensive dataset was used containing all necessary features for the project.
#   [  Yes   ] Data preparation was thorough and documented
#            Note: Included cleaning, handling missing values, encoding categorical variables, and feature engineering.
#   [  Yes   ] No data leakage between train and test sets
#            Note: Train/test split was performed before modelling and no test data was used during training.
#   [  Yes   ] Multiple modelling techniques were compared
#            Note: Logistic Regression, Random Forest, and Gradient Boosting were implemented and evaluated.
#   [  Yes   ] Hyperparameters were tuned appropriately
#            Note: GridSearchCV was applied to Random Forest to improve performance.
#   [  Yes   ] Results are reproducible (random seed set)
# ...

# %% [markdown]
# ### Review Process Notes:
#
# - A comprehensive review of the CRISP-DM process was conducted to ensure that all stages were completed effectively and no critical steps were overlooked. The data preparation phase included thorough cleaning, feature selection, encoding, and handling of missing values, resulting in a structured dataset suitable for modelling.
#
# - Multiple machine learning models were implemented and compared, including Logistic Regression, Random Forest, and Gradient Boosting. Hyperparameter tuning was applied to improve model performance, and appropriate evaluation metrics were used to assess the results. Measures were taken to prevent data leakage, and reproducibility was ensured through the use of a fixed random seed 42.
#
# - However, some limitations were identified. While class imbalance was recognised and partially addressed, further techniques could be applied to improve model performance and fairness. Additionally, deeper analysis of potential bias and ethical implications could strengthen the overall evaluation.

# %% [markdown]
# ---
# ### Task 3: Determine Next Steps
#
# Based on the evaluation results and process review, decide on the next course of action. The three main options are:
#
# 1. **Proceed to Deployment:** The model meets all criteria and is ready for deployment.
# 2. **Iterate:** Go back to a previous phase (e.g., Data Preparation or Modelling) to improve the model before deployment.
# 3. **Terminate:** The project is not viable in its current form and should be re-scoped or abandoned.
#
# **Instructions:** Document your decision and provide a clear rationale.

# %%
# Determine and document the next steps.

next_steps = {
    "decision": "Proceed to Deployment",

    "rationale": "The Random Forest model demonstrates strong performance in identifying approved projects, with high recall and F1-score. While the model is affected by class imbalance and shows limited ability to distinguish non-approved projects, it is still effective as a decision-support tool.",

    "if_iterating": {
        "return_to_phase": "Phase 3: Data Preparation",
        "specific_actions": [
            "Apply advanced techniques to handle class imbalance (e.g., SMOTE or resampling)",
            "Improve feature engineering to enhance class separation",
            "Experiment with additional models or threshold tuning"
        ]
    },

    "if_deploying": {
        "selected_model": "Random Forest",
        "deployment_priority": "High"
    }
}

# %%
# Display the decision
print("=" * 60)
print("NEXT STEPS DECISION")
print("=" * 60)
print(f"\nDecision  : {next_steps['decision']}")
print(f"Rationale : {next_steps['rationale']}")

if next_steps['decision'] == 'Iterate':
    print(f"\nReturn to: {next_steps['if_iterating']['return_to_phase']}")
    for action in next_steps['if_iterating']['specific_actions']:
        print(f"  - {action}")
elif next_steps['decision'] == 'Proceed to Deployment':
    print(f"\nModel to deploy: {next_steps['if_deploying']['selected_model']}")
    print(f"Priority: {next_steps['if_deploying']['deployment_priority']}")
# Out:
# ...
# NEXT STEPS DECISION
# ...
#
# Decision  : Proceed to Deployment
# Rationale : The Random Forest model demonstrates strong performance in identifying approved projects, with high recall and F1-score. While the model is affected by class imbalance and shows limited ability to distinguish non-approved projects, it is still effective as a decision-support tool.
#
# Model to deploy: Random Forest
# Priority: High

# %% [markdown]
# ### Notes about The Next Step plan

# %% [markdown]
# - Based on the evaluation results and process review, the decision is to proceed with deployment of the selected model. The Random Forest model demonstrates strong performance in identifying approved projects, achieving high recall and F1-score. This makes it effective for supporting the screening process by identifying applications that are likely to be approved.
#
# - Although the model shows limitations in distinguishing non-approved projects due to class imbalance, it still provides practical value as a decision-support tool. It can assist in prioritising applications and reducing manual workload, which aligns with the original business objectives.
#
# - If further improvements were required, the project could return to the data preparation phase to address class imbalance more effectively and enhance feature engineering. However, for the current scope of the project, the model is considered suitable for deployment.
